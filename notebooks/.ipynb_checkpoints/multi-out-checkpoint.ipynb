# %%
try:
    # %tensorflow_version only exists in Colab.
    # %tensorflow_version 2.x
except Exception:
    pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2

def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %%
# Specify data URI
URI = '../data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model

inputs = Input(shape = (norm_train_X.shape[1], ))
x = Dense(64, activation = 'relu')(inputs)
y1 = Dense(1)(x)
x1 = Dense(64)(x)
y2 = Dense(1)(x1)

model = Model(inputs, (y1, y2))

plot_model(model, show_shapes = True)
# Out:
# 2022-07-30 06:32:26.039022: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-07-30 06:32:26.039230: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-07-30 06:32:26.039351: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (c1ad075bfae4): /proc/driver/nvidia/version does not exist
# 2022-07-30 06:32:26.040615: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import mean_squared_error

# %%
model.compile(optimizer = Adam(learning_rate = 0.01), loss = mean_squared_error, metrics = ['mse'])

# %%
history = model.fit(norm_train_X, train_Y, epochs = 10, validation_data = (norm_test_X, test_Y))
# Out:
# 2022-07-30 06:32:29.426915: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/10
# 20/20 [==============================] - 1s 13ms/step - loss: 710.0127 - dense_1_loss: 493.5650 - dense_3_loss: 216.4476 - dense_1_mse: 493.5650 - dense_3_mse: 216.4476 - val_loss: 375.3404 - val_dense_1_loss: 345.8214 - val_dense_3_loss: 29.5190 - val_dense_1_mse: 345.8214 - val_dense_3_mse: 29.5190
# Epoch 2/10
# 20/20 [==============================] - 0s 4ms/step - loss: 281.3176 - dense_1_loss: 243.5901 - dense_3_loss: 37.7276 - dense_1_mse: 243.5901 - dense_3_mse: 37.7276 - val_loss: 120.9728 - val_dense_1_loss: 100.6631 - val_dense_3_loss: 20.3096 - val_dense_1_mse: 100.6631 - val_dense_3_mse: 20.3096
# Epoch 3/10
# 20/20 [==============================] - 0s 5ms/step - loss: 76.7961 - dense_1_loss: 50.0963 - dense_3_loss: 26.6997 - dense_1_mse: 50.0963 - dense_3_mse: 26.6997 - val_loss: 41.3357 - val_dense_1_loss: 27.5422 - val_dense_3_loss: 13.7935 - val_dense_1_mse: 27.5422 - val_dense_3_mse: 13.7935
# Epoch 4/10
# 20/20 [==============================] - 0s 6ms/step - loss: 41.5364 - dense_1_loss: 23.3153 - dense_3_loss: 18.2211 - dense_1_mse: 23.3153 - dense_3_mse: 18.2211 - val_loss: 30.9801 - val_dense_1_loss: 17.6135 - val_dense_3_loss: 13.3666 - val_dense_1_mse: 17.6135 - val_dense_3_mse: 13.3666
# Epoch 5/10
# 20/20 [==============================] - 0s 6ms/step - loss: 31.5155 - dense_1_loss: 17.3733 - dense_3_loss: 14.1422 - dense_1_mse: 17.3733 - dense_3_mse: 14.1422 - val_loss: 22.7468 - val_dense_1_loss: 14.4822 - val_dense_3_loss: 8.2646 - val_dense_1_mse: 14.4822 - val_dense_3_mse: 8.2646
# Epoch 6/10
# 20/20 [==============================] - 0s 6ms/step - loss: 27.9285 - dense_1_loss: 14.7233 - dense_3_loss: 13.2052 - dense_1_mse: 14.7233 - dense_3_mse: 13.2052 - val_loss: 21.3705 - val_dense_1_loss: 12.0889 - val_dense_3_loss: 9.2817 - val_dense_1_mse: 12.0889 - val_dense_3_mse: 9.2817
# Epoch 7/10
# 20/20 [==============================] - 0s 5ms/step - loss: 25.3956 - dense_1_loss: 12.7233 - dense_3_loss: 12.6723 - dense_1_mse: 12.7233 - dense_3_mse: 12.6723 - val_loss: 19.2899 - val_dense_1_loss: 11.0113 - val_dense_3_loss: 8.2786 - val_dense_1_mse: 11.0113 - val_dense_3_mse: 8.2786
# Epoch 8/10
# 20/20 [==============================] - 0s 5ms/step - loss: 23.6696 - dense_1_loss: 11.5797 - dense_3_loss: 12.0898 - dense_1_mse: 11.5797 - dense_3_mse: 12.0898 - val_loss: 18.3397 - val_dense_1_loss: 10.0914 - val_dense_3_loss: 8.2483 - val_dense_1_mse: 10.0914 - val_dense_3_mse: 8.2483
# Epoch 9/10
# 20/20 [==============================] - 0s 5ms/step - loss: 22.9033 - dense_1_loss: 10.8259 - dense_3_loss: 12.0774 - dense_1_mse: 10.8259 - dense_3_mse: 12.0774 - val_loss: 17.0719 - val_dense_1_loss: 9.3777 - val_dense_3_loss: 7.6942 - val_dense_1_mse: 9.3777 - val_dense_3_mse: 7.6942
# Epoch 10/10
# 20/20 [==============================] - 0s 5ms/step - loss: 22.5492 - dense_1_loss: 10.0175 - dense_3_loss: 12.5317 - dense_1_mse: 10.0175 - dense_3_mse: 12.5317 - val_loss: 18.0267 - val_dense_1_loss: 9.1531 - val_dense_3_loss: 8.8737 - val_dense_1_mse: 9.1531 - val_dense_3_mse: 8.8737

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Loss curve")
plt.grid(linestyle='--')

# %%
y1, y2 = model.predict(norm_test_X)

# %%
plt.scatter(y1, test_Y[0], alpha = 0.6)
plt.grid(linestyle = '--')

# %%
plt.scatter(y2, test_Y[1], alpha = 0.6)
plt.grid(linestyle = '--')

# %%
from prophet import Prophet
